# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
print("Num1=",Num1)
Num2=30
print("Num2=",Num2)
Add=Num1+Num2
print("Add=",Add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
BMI=float(input("Enter the BMI ="))
if(BMI<=18.5):
    print("under weight")
elif(BMI<=24.9):
    print("normal range")  
elif(BMI<29.9):
    print("over weight") 
else:
    print("obese")
# Out:
# Enter the BMI = 30.5
# obese
