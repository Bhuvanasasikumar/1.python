# %%
user=int(input("Enter the amount:"))
if(user>0):
    print(user,"is positive amount")
elif(user<0):
    print(user,"is negative amount")
else:
    print(user)
# Out:
# Enter the amount: 34
# 34 is positive number

# %%
user=int(input("Enter the passcode"))
if(user==10):
    n=10
    total=n*(n+1)//2
    print("passcode is right")
else:
    print("Enter the valid passcode")
# Out:
# Enter the passcode 34
# Enter the valid passcode

# %%
n=int(input("Enter the transaction number:"))
s=str(n)
s=s[::-1]
n=int(s)
print(n)
# Out:
# Enter the transaction number: 456
# 654

# %%
num = int(input("Enter the user id:"))

if num > 1:
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            print("given id is not prime number ")
            break   
    else:
         print("given id is  prime number")
# Out:
# Enter the user id: 3
# given id is  prime number

# %%
def fact(n):
     if (n==1 or n==0):
        
        return 1
    
     else:
        
        return (n * fact(n - 1)) 
num = 5; 
print("number : ",num)
print("Factorial : ",fact(num))
# Out:
# number :  5
# Factorial :  120

# %%
s="Tamil"
a=list(s)
a[0],a[-1] = a[-1], a[0]
res=''.join(a)
print(res)
# Out:
# lamiT

# %%
num=5
print(bin(num))
# Out:
# 0b101

# %%
text=" The king of jungle is Lion"
word=max(text.split(), key=len)
print(word)
# Out:
# jungle

# %%
s1 = "listen"
s2 = "silent"

print("Yes" if sorted(s1) == sorted(s2) else "No")
# Out:
# Yes
