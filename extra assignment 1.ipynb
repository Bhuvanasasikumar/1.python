# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
ins=input("Enter your institute name:")
# Out:
# Enter your institute name: HOPE AI

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
school=input("Enter your school name")
deg=input   ("Enter your Degree:")
# Out:
# Enter your name: Bhuvaneswari
# Enter your age: 35
# Enter your school name AVHSSchool
# Enter your Degree: MSc

# %%
a=10
print("a=",a)
b=20
print("b=",b)
add=a+b
print("add=",add)
# Out:
# a= 10
# b= 20
# add= 30

# %%
a1=45
print("a=",a)
b1=5
print("b=",b)
sub=a-b
print("sub=",sub)
# Out:
# a= 10
# b= 20
# sub= -10

# %%
a=10
print("a=",a)
b=20
print("b=",b)
mul=a*b
print("mul=",mul)
# Out:
# a= 10
# b= 20
# mul= 200

# %%
a=73
print("a=",a)
b=3.3
print("b=",b)
floatdiv=a/b
print("float div=",floatdiv)
# Out:
# a= 73
# b= 3.3
# float div= 22.12121212121212

# %%
a=73
print("a=",a)
b=3.3
print("b=",b)
floordiv=a//b
print("floor div=",floordiv)
# Out:
# a= 73
# b= 3.3
# floor div= 22.0

# %%
a=10
print("a=",a)
b=3
print("b=",b)
mod=a%b
print("mod=",mod)
# Out:
# a= 10
# b= 3
# mod= 1

# %%
a=10
print("a=",a)
b=20
print("b=",b)
power=a**b
print("power=",power)
# Out:
# a= 10
# b= 20
# power= 100000000000000000000
