# %%
age=int(input("Enter the Number"))
if(age>=18):
    print("eligible")
else:
    print("not eligible")
# Out:
# Enter the Number 16
# not eligible

# %%
lar=[22,24,67,87,98,78]
result=max(lar)
print("largest number is",result)
# Out:
# largest number is 98

# %%
ename=input("Enter the name:")
esal=float(input("Enter the salary"))
if(esal>50000):
    print(esal*0.10)
else:
    print("not eligible for bonus")
# Out:
# Enter the name: ram
# Enter the salary 35000
# not eligible for bonus

# %%
num=int(input("Enter the Number"))
if(num%2==1):
    print("Given Number is odd")
else:
    print("Given number is even")
# Out:
# Enter the Number 32
# Given number is even

# %%
sent="communication is the best"
rev=sent[::-1]
print(rev)
# Out:
# tseb eht si noitacinummoc

# %%
sname=input("Enter the Name:")
smark=float(input("Enter the Marks"))
if(smark>=40):
    print("Pass")
else:
    print("Fail")
# Out:
# Enter the Name: rani
# Enter the Marks 40
# Pass

# %%
billamo=float(input("Enter the amount"))
if(billamo>100):
    print(billamo-billamo*0.20)
else:
    print(billamo)
# Out:
# Enter the amount 101
# 80.8

# %%
balance=10000
withdraw=int(input("Enter the amount to be withdraw:"))
if(withdraw<balance):
    updatedbalance=balance-withdraw
    print("Available Balance is:",updatedbalance)
else:
    print("Insufficient Balance")
# Out:
# Enter the amount to be withdraw: 2000
# Available Balance is: 8000

# %%
year=int(input("Enter the Year:"))
if(year%4==0):
    print("Leap Year")
else:
    print("Normal Year")
# Out:
# Enter the Year: 2028
# Leap Year

# %%
n=[23,24,241,26,45,44,76,98]
for val in n:
    if(val%2==0):
        print("even numbers are:",val)
# Out:
# even numbers are: 24
# even numbers are: 26
# even numbers are: 44
# even numbers are: 76
# even numbers are: 98
