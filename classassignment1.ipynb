# %%
from subAIasign  import subfieldsinAI

# %%
subfieldsinAI.subfields()
# Out:
# Subfields in AI are:
# Machine learning
# Neural networks
# vision
# robotics
# speech processing
# Natural language processing

# %%
subfieldsinAI.oddeven()
# Out:
# Enter the number: 53423
# 53423 is odd number
# 53423

# %%
subfieldsinAI.eligible1()
# Out:
# Your Gender: male
# Your age 25
# Eligible

# %%
subfieldsinAI.percentage()
# Out:
# SUBJECT1: 87
# SUBJECT2: 76
# SUBJECT3: 67
# SUBJECT4: 56
# SUBJECT5: 98
# total: 384
# percentage: 76.8
# 76.8

# %%
subfieldsinAI.triangle()
# Out:
# Height: 56
# Breadth: 65
# Area of Triangle: 1820.0
# Height1: 45
# Height2: 65
# Breadth: 33
# Perimeter of Triangle: 143.0
# 143.0
